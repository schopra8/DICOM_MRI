# %% [markdown]
# ## Part 1: Parse the DICOM Images and Contour Files
# * I qualitatively checked that I was parsing the contours correctly. I did so by examining the pairings of contours and dicom files (as shown later in this ipython notebook) to make sure that the correct contour and DICOM files were being paired up correctly. Then I sampled a few files from the data loader, visualizing both the contour and the original image. As someone who doesn't know that much about medical imaging, it seems like the contours line up well with white regions in the cetner of the photos -- but I don't have much intuition as to whether this is correct. So, I then looked up the contour file that the visualized contour belonged to, scanned the coordinates in the original `.txt` file to qualitatively inspect if the shaded region was in the same area as defined by the file coordinates.
# * In order to integrate with your production code base, I tucked the provided functions into several classes, i.e. `IContourDataParser`, `DicomParser`, `MRIDataLoader`. Additionally, I modified the `_poly_to_mask` function. The polygon contours were not appearing when I visualized the masks with the implementation provided in the starter code, so I tweaked the colors.

# %% [markdown]
# ## Part 2: Model Training Pipeline
# * First, I extended the MRIDataLoader to take another initial paramter to determine minibatch size. Then, I added code that first requires the user to `load()` the data before fetching it via minibatches.
# * Previously I had verified that the dicom, contour files worked. First, I made sure that introducing shuffling did not disrupt the pairing btween dicom and contour files. The minibatch code utilized in this notebook is the final version and has shuffling per epoch built in. Thus, the correctly paired contour, dicom files below are post-shuffling. Second, I wrote two simple tests, near the bottom of this notebook, that accumulates the contour files and dicom files provided across the minibatches and checks to make sure that there are no repeats when we cycling through one epoch and that all data is provided. Third, I wrote another test to make sure that if one cycles through a second epoch then one gets all the same contour files and dicom files, in a different order. This is a flaky test, as it assumes that the dataset is sufficiently large -- at which point the probability of getting the exact same ordering of files twice is very unlikely. Fourth, I wrote another test to make sure that the minibatches are of appropriate size -- when the number of data points is not divisible by the minibatch size.
# * I would probably rewrite my contour file parser so that it could properly handle both i-contour and o-contour files. I would spend more time thinking of a better test for randomly shuffling and spend more time brainstorming additional unit tests.

# %%
from parsing import MRIDataLoader
import matplotlib.pyplot as plt
import pprint

# %%
# Load Data
dataLoader = MRIDataLoader(
    './final_data/contourfiles',
    './final_data/dicoms',
    './final_data/link.csv',
    8
)
dataLoader.load()

# %% [markdown]
# # Inspecting Contour Mask + DICOM File Matching

# %%
combined = list(zip(dataLoader.contour_mask_files, dataLoader.dicom_files))
pprint.pprint(combined)
# Out:
# [('./final_data/contourfiles/SC-HF-I-2/i-contours/IM-0001-0060-icontour-manual',
#   './final_data/dicoms/SCD0000201/60'),
#  ('./final_data/contourfiles/SC-HF-I-5/i-contours/IM-0001-0187-icontour-manual',
#   './final_data/dicoms/SCD0000401/187'),
#  ('./final_data/contourfiles/SC-HF-I-6/i-contours/IM-0001-0119-icontour-manual',
#   './final_data/dicoms/SCD0000501/119'),
#  ('./final_data/contourfiles/SC-HF-I-1/i-contours/IM-0001-0159-icontour-manual',
#   './final_data/dicoms/SCD0000101/159'),
#  ('./final_data/contourfiles/SC-HF-I-4/i-contours/IM-0001-0087-icontour-manual',
#   './final_data/dicoms/SCD0000301/87'),
#  ('./final_data/contourfiles/SC-HF-I-2/i-contours/IM-0001-0200-icontour-manual',
#   './final_data/dicoms/SCD0000201/200'),
#  ('./final_data/contourfiles/SC-HF-I-4/i-contours/IM-0001-0120-icontour-manual',
#   './final_data/dicoms/SCD0000301/120'),
#  ('./final_data/contourfiles/SC-HF-I-6/i-contours/IM-0001-0109-icontour-manual',
# ...

# %%
# Plot Minibatch
def plot_minibatches(imgs, contours):
    for idx in range(len(imgs)):
        img = imgs[idx]
        contour = contours[idx]

        fig = plt.figure()
        a = fig.add_subplot(1, 2, 1)
        plt.imshow(img['pixel_data'])
        a.set_title('DICOM Image')
        
        a = fig.add_subplot(1, 2, 2)
        plt.imshow(contour.reshape(256, 256))
        a.set_title('Contour Mask')
        
        plt.show()

# %% [markdown]
# # Qualitative Check: Visualize DICOM Image & Contour Mask

# %%
# Minibatch 1
contour_masks, imgs, c_files, d_files = dataLoader.fetch_minibatch()
plot_minibatches(imgs, contour_masks)

pprint.pprint(list(zip(c_files, d_files)))
# Out:
# [('./final_data/contourfiles/SC-HF-I-2/i-contours/IM-0001-0060-icontour-manual',
#   './final_data/dicoms/SCD0000201/60'),
#  ('./final_data/contourfiles/SC-HF-I-5/i-contours/IM-0001-0187-icontour-manual',
#   './final_data/dicoms/SCD0000401/187'),
#  ('./final_data/contourfiles/SC-HF-I-6/i-contours/IM-0001-0119-icontour-manual',
#   './final_data/dicoms/SCD0000501/119'),
#  ('./final_data/contourfiles/SC-HF-I-1/i-contours/IM-0001-0159-icontour-manual',
#   './final_data/dicoms/SCD0000101/159'),
#  ('./final_data/contourfiles/SC-HF-I-4/i-contours/IM-0001-0087-icontour-manual',
#   './final_data/dicoms/SCD0000301/87'),
#  ('./final_data/contourfiles/SC-HF-I-2/i-contours/IM-0001-0200-icontour-manual',
#   './final_data/dicoms/SCD0000201/200'),
#  ('./final_data/contourfiles/SC-HF-I-4/i-contours/IM-0001-0120-icontour-manual',
#   './final_data/dicoms/SCD0000301/120'),
#  ('./final_data/contourfiles/SC-HF-I-6/i-contours/IM-0001-0109-icontour-manual',
# ...

# %% [markdown]
# # Unit Tests

# %%
def test_all_contour_data_received():
    # Test assumes that there are 96 datasamples
    # Test that all 96 unique contours are received 
    dataLoader = MRIDataLoader(
    './final_data/contourfiles',
    './final_data/dicoms',
    './final_data/link.csv',
    8
    )
    dataLoader.load()  
    
    c_masks = []
    imgs = []
    c_files = []
    d_files = []
    
    for i in range(12):
        contour_masks, images, contour_files, dicom_files = dataLoader.fetch_minibatch()
        c_masks.extend(contour_masks)
        imgs.extend(images)
        c_files.extend(contour_files)
        d_files.extend(dicom_files)
        
    assert len(list(set(c_files))) == 96

def test_all_dicom_data_received():
    # Test assumes that there are 96 datasamples
    # Test that all 96 unique dicoms are received 
    dataLoader = MRIDataLoader(
        './final_data/contourfiles',
        './final_data/dicoms',
        './final_data/link.csv',
        8
    )
    dataLoader.load()  
    
    c_masks = []
    imgs = []
    c_files = []
    d_files = []
    
    for i in range(12):
        contour_masks, images, contour_files, dicom_files = dataLoader.fetch_minibatch()
        c_masks.extend(contour_masks)
        imgs.extend(images)
        c_files.extend(contour_files)
        d_files.extend(dicom_files)
        
    assert len(list(set(d_files))) == 96

# %%
test_all_contour_data_received()
test_all_dicom_data_received()

# %%
def test_random_shuffling_contours():
    # Flaky Test: Assumes sufficiently large dataset
    # Test that order of the contours is different per epoch
    dataLoader = MRIDataLoader(
        './final_data/contourfiles',
        './final_data/dicoms',
        './final_data/link.csv',
        96
    )
    dataLoader.load()
    
    c_masks_1, imgs_1, c_files_1, d_files_1 = dataLoader.fetch_minibatch()
    c_masks_2, imgs_2, c_files_2, d_files_2 = dataLoader.fetch_minibatch()
    
    assert(c_files_1 != c_files_2) # Different Order
    assert(set(c_files_1) == set(c_files_2)) # Same Files
    
def test_random_shuffling_dicoms():
    # Flaky Test: Assumes sufficiently large dataset
    # Test that order of the dicoms is different per epoch
    dataLoader = MRIDataLoader(
        './final_data/contourfiles',
        './final_data/dicoms',
        './final_data/link.csv',
        96
    )
    dataLoader.load()
    
    c_masks_1, imgs_1, c_files_1, d_files_1 = dataLoader.fetch_minibatch()
    c_masks_2, imgs_2, c_files_2, d_files_2 = dataLoader.fetch_minibatch()
    
    assert(d_files_1 != d_files_2) # Different Order
    assert(set(d_files_1) == set(d_files_2)) # Same Files

# %%
test_random_shuffling_contours()
test_random_shuffling_dicoms()

# %%
def test_undivisible_minibatch_contours():
    # Assumes dataset of 96
    # Make sure that the last minibatch is appropriate size.
    dataLoader = MRIDataLoader(
        './final_data/contourfiles',
        './final_data/dicoms',
        './final_data/link.csv',
        90
    )
    dataLoader.load()
    
    c_masks_1, imgs_1, c_files_1, d_files_1 = dataLoader.fetch_minibatch()
    c_masks_2, imgs_2, c_files_2, d_files_2 = dataLoader.fetch_minibatch()
    
    assert len(c_files_2) == 6
    
def test_undivisible_minibatch_dicoms():
    # Assumes dataset of 96
    # Make sure that the last minibatch is appropriate size.
    dataLoader = MRIDataLoader(
        './final_data/contourfiles',
        './final_data/dicoms',
        './final_data/link.csv',
        90
    )
    dataLoader.load()
    
    c_masks_1, imgs_1, c_files_1, d_files_1 = dataLoader.fetch_minibatch()
    c_masks_2, imgs_2, c_files_2, d_files_2 = dataLoader.fetch_minibatch()
    
    assert len(d_files_2) == 6

# %%
test_undivisible_minibatch_contours()
test_undivisible_minibatch_dicoms()

# %%
def test_undivisible_minibatch_epoch_transition_contours():
    # Assumes dataset of 96
    # Make sure that the new epoch as appropriately sized minibatch
    dataLoader = MRIDataLoader(
        './final_data/contourfiles',
        './final_data/dicoms',
        './final_data/link.csv',
        90
    )
    dataLoader.load()
    
    c_masks_1, imgs_1, c_files_1, d_files_1 = dataLoader.fetch_minibatch()
    c_masks_2, imgs_2, c_files_2, d_files_2 = dataLoader.fetch_minibatch()
    c_masks_3, imgs_3, c_files_3, d_files_3 = dataLoader.fetch_minibatch() 

    assert len(c_files_3) == 90
    
def test_undivisible_minibatch_epoch_transition_dicoms():
    # Assumes dataset of 96
    # Make sure that the new epoch as appropriately sized minibatch
    dataLoader = MRIDataLoader(
        './final_data/contourfiles',
        './final_data/dicoms',
        './final_data/link.csv',
        90
    )
    dataLoader.load()
    
    c_masks_1, imgs_1, c_files_1, d_files_1 = dataLoader.fetch_minibatch()
    c_masks_2, imgs_2, c_files_2, d_files_2 = dataLoader.fetch_minibatch()
    c_masks_3, imgs_3, c_files_3, d_files_3 = dataLoader.fetch_minibatch() 

    assert len(d_files_3) == 90

# %%
test_undivisible_minibatch_epoch_transition_contours()
test_undivisible_minibatch_epoch_transition_dicoms()
